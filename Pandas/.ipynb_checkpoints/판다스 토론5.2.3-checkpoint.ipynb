# %% [markdown]
# ### 5.2.3 색인하기, 선택하기, 거르기
# ![table5-4.png](attachment:table5-4.png)

# %%
from numpy.random import randn
import numpy as np
from pandas import Series, DataFrame
import pandas as pd
np.set_printoptions(precision=4)

# %% [markdown]
# #### 1. 다음과 같으 DataFrame을 만들어, 다음 질의에 답하시오.
# ![5.2.3-prob1.PNG](attachment:5.2.3-prob1.PNG)

# %% [markdown]
# ##### (1) 행은 Utah, Colorado행 순서대로, 컬럼은 three, one 컬럼순서대로 구성된 df를 만들어 출력하라. 단, df.loc 함수를 이용하라.

# %%
a = DataFrame(np.arange(16).reshape(4,4),index = "Ohio Colorado Utaj NewYork".split())
a.columns = "one,two,three,four".split(',')

a
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utaj        8    9     10    11
# NewYork    12   13     14    15

# %% [markdown]
# ##### (2) 1\~2행과 0~2컬럼으로 구성된 df를 만들어 출력하라. 단, df.iloc함수를 이용하라.

# %%
df = a.

# %% [markdown]
# ##### (3) four > 10 인 행의  모든 컬럼 값을  20으로 설정하시오.
